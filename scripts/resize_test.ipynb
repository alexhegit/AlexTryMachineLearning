# %%
import cv2
import sys
import os

# %%
import matplotlib.pyplot as plt
# display plots in this notebook
# %matplotlib inline
# set display defaults
plt.rcParams['figure.figsize'] = (10, 10)        # large images
plt.rcParams['image.interpolation'] = 'nearest'  # don't interpolate: show square pixels
plt.rcParams['image.cmap'] = 'gray'  # use grayscale output rather than a (potentially misleading) color heatmap

# %%
img = cv2.imread('./dolphin1.jpeg', cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(img)

# %%
print('Original Dim : ', img.shape)
# Out:
# Original Dim :  (402, 600, 3)

# %%
width = 256
height = 256
dim = (width, height)

# %%
resized_img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

# %%
print('Resize Dim: ', resized_img.shape)
# Out:
# Resize Dim:  (256, 256, 3)

# %% [markdown]
# #cv2.imshow("Resized image", resized)
# #cv2.waitKey(0)
# #cv2.destroyAllWindows()

# %%
plt.imshow(resized_img)

# %%
cv2.imwrite("test.jpeg", resized_img, [cv2.IMWRITE_JPEG_QUALITY, 100])
# Out:
# True
